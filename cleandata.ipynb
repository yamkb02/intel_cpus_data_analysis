# %%
import pandas as pd
import numpy as np
df = pd.read_csv('intel.csv')
df
# Out:
#       Unnamed: 0                                              Model  \
# 0              0          Intel® Core™ i9-10900X X-series Processor
# 1              1          Intel® Core™ i9-10920X X-series Processor
# 2              2          Intel® Core™ i9-10940X X-series Processor
# 3              3  Intel® Core™ i9-10980XE Extreme Edition Processor
# 4              4           Intel® Core™ i7-9800X X-series Processor
# ...          ...                                                ...
# 1071        1071                  Intel® Core™2 Duo Processor U7500
# 1072        1072              Intel® Core™2 Extreme Processor X6800
# 1073        1073                   Intel® Core™ Duo Processor L2400
# 1074        1074                   Intel® Core™ Duo Processor T2500
# 1075        1075                   Intel® Core™ Duo Processor U2500
#
#                     Price MarketSegment Lithography  CoreCount  ThreadCount  \
# 0       $648.00 - $658.00       Desktop       14 nm       10.0         20.0
# 1       $759.00 - $769.00       Desktop       14 nm       12.0         24.0
# 2       $863.00 - $873.00       Desktop       14 nm       14.0         28.0
# 3     $1076.00 - $1086.00       Desktop       14 nm       18.0         36.0
# 4                 $589.00       Desktop       14 nm        8.0         16.0
# ...                   ...           ...         ...        ...          ...
# 1071                  NaN        Mobile       65 nm        2.0          NaN
# 1072                  NaN       Desktop       65 nm        2.0          NaN
# 1073                  NaN        Mobile       65 nm        2.0          NaN
# 1074                  NaN        Mobile       65 nm        2.0          NaN
# 1075                  NaN        Mobile       65 nm        2.0          NaN
#
#      ClockSpeedMax TurboBoostMaxTechMaxFreq ClockSpeed  \
# 0         4.50 GHz                 4.70 GHz   3.70 GHz
# 1         4.60 GHz                 4.80 GHz   3.50 GHz
# 2         4.60 GHz                 4.80 GHz   3.30 GHz
# 3         4.60 GHz                 4.80 GHz   3.00 GHz
# 4         4.40 GHz                 4.50 GHz   3.80 GHz
# ...            ...                      ...        ...
# 1071           NaN                      NaN   1.06 GHz
# 1072           NaN                      NaN   2.93 GHz
# 1073           NaN                      NaN   1.66 GHz
# 1074           NaN                      NaN   2.00 GHz
# 1075           NaN                      NaN   1.20 GHz
#
#                             Cache          Bus MaxTDP BornOnDate
# 0     19.25 MB Intel® Smart Cache  8 GT/s DMI3  165 W      Q4'19
# 1     19.25 MB Intel® Smart Cache  8 GT/s DMI3  165 W      Q4'19
# 2     19.25 MB Intel® Smart Cache  8 GT/s DMI3  165 W      Q4'19
# 3     24.75 MB Intel® Smart Cache  8 GT/s DMI3  165 W      Q4'19
# 4      16.5 MB Intel® Smart Cache       8 GT/s  165 W      Q4'18
# ...                           ...          ...    ...        ...
# 1071                2 MB L2 Cache      533 MHz   10 W      Q3'06
# 1072                4 MB L2 Cache     1066 MHz   75 W      Q3'06
# 1073                2 MB L2 Cache      667 MHz   15 W      Q1'06
# 1074                2 MB L2 Cache      667 MHz   31 W      Q1'06
# 1075                2 MB L2 Cache      533 MHz    9 W      Q1'06
#
# [1076 rows x 14 columns]

# %%
df.drop("TurboBoostMaxTechMaxFreq", axis=1, inplace=True)
df.drop("Unnamed: 0", axis=1, inplace=True)
df.dropna(inplace=True, subset="Price")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 595 entries, 0 to 1023
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Model          595 non-null    object
#  1   Price          595 non-null    object
#  2   MarketSegment  595 non-null    object
#  3   Lithography    595 non-null    object
#  4   CoreCount      595 non-null    float64
#  5   ThreadCount    567 non-null    float64
#  6   ClockSpeedMax  511 non-null    object
#  7   ClockSpeed     431 non-null    object
#  8   Cache          595 non-null    object
#  9   Bus            423 non-null    object
#  10  MaxTDP         420 non-null    object
#  11  BornOnDate     595 non-null    object
# dtypes: float64(2), object(10)
# memory usage: 60.4+ KB

# %%
df = df.reset_index(drop=True)

def convert_price(price):
    try:
        min_value, max_value = map(float, price.replace('$', '').split(' - '))
        return (min_value + max_value) / 2
    except:
        return float(price.replace('$', ''))

df["Price"] = df["Price"].apply(convert_price)

# %%
df = pd.concat([df, pd.get_dummies(df.MarketSegment)], axis=1).drop("MarketSegment", axis=1)

# %%
df
# Out:
#                                                  Model   Price Lithography  \
# 0            Intel® Core™ i9-10900X X-series Processor   653.0       14 nm
# 1            Intel® Core™ i9-10920X X-series Processor   764.0       14 nm
# 2            Intel® Core™ i9-10940X X-series Processor   868.0       14 nm
# 3    Intel® Core™ i9-10980XE Extreme Edition Processor  1081.0       14 nm
# 4             Intel® Core™ i7-9800X X-series Processor   589.0       14 nm
# ..                                                 ...     ...         ...
# 590                  Intel® Core™2 Duo Processor T9400   290.5       45 nm
# 591                 Intel® Core™2 Quad Processor Q9300   200.0       45 nm
# 592                 Intel® Core™2 Quad Processor Q9550   287.0       45 nm
# 593                  Intel® Core™2 Duo Processor E8400   179.0       45 nm
# 594                  Intel® Core™2 Duo Processor E8500   200.0       45 nm
#
#      CoreCount  ThreadCount ClockSpeedMax ClockSpeed  \
# 0         10.0         20.0      4.50 GHz   3.70 GHz
# 1         12.0         24.0      4.60 GHz   3.50 GHz
# 2         14.0         28.0      4.60 GHz   3.30 GHz
# 3         18.0         36.0      4.60 GHz   3.00 GHz
# 4          8.0         16.0      4.40 GHz   3.80 GHz
# ..         ...          ...           ...        ...
# 590        2.0          NaN           NaN   2.53 GHz
# 591        4.0          NaN           NaN   2.50 GHz
# 592        4.0          NaN           NaN   2.83 GHz
# 593        2.0          NaN           NaN   3.00 GHz
# 594        2.0          NaN           NaN   3.16 GHz
#
#                            Cache          Bus MaxTDP BornOnDate  Desktop  \
# 0    19.25 MB Intel® Smart Cache  8 GT/s DMI3  165 W      Q4'19     True
# 1    19.25 MB Intel® Smart Cache  8 GT/s DMI3  165 W      Q4'19     True
# 2    19.25 MB Intel® Smart Cache  8 GT/s DMI3  165 W      Q4'19     True
# 3    24.75 MB Intel® Smart Cache  8 GT/s DMI3  165 W      Q4'19     True
# 4     16.5 MB Intel® Smart Cache       8 GT/s  165 W      Q4'18     True
# ..                           ...          ...    ...        ...      ...
# 590                6 MB L2 Cache     1066 MHz   35 W      Q3'08    False
# 591                6 MB L2 Cache     1333 MHz   95 W      Q1'08     True
# 592               12 MB L2 Cache     1333 MHz   95 W      Q1'08     True
# 593                6 MB L2 Cache     1333 MHz   65 W      Q1'08     True
# 594                6 MB L2 Cache     1333 MHz   65 W      Q1'08     True
#
#      Embedded  Mobile
# 0       False   False
# 1       False   False
# 2       False   False
# 3       False   False
# 4       False   False
# ..        ...     ...
# 590     False    True
# 591     False   False
# 592     False   False
# 593     False   False
# 594     False   False
#
# [595 rows x 14 columns]

# %%
print(df["Lithography"].unique())
# Out:
# ['14 nm' '22 nm' '32 nm' 'Intel 7' '10 nm SuperFin' '10 nm' '45 nm']

# %%
df.loc[df["Lithography"] == "Intel 7", "Lithography"] = 10
df["Lithography"] = pd.to_numeric(df["Lithography"].str[:2], errors="coerce")

# %%
print(df["ClockSpeedMax"].unique())

df["ClockSpeedMax"] = pd.to_numeric(df["ClockSpeedMax"].str.replace(" GHz", ""), errors='coerce')


print(df["ClockSpeed"].unique())

df["ClockSpeed"] = df["ClockSpeed"].str[:-4]
df["ClockSpeed"] = pd.to_numeric(df["ClockSpeed"], errors='coerce')

# Convert MHz to GHz
df.loc[df["ClockSpeed"] > 100, "ClockSpeed"] /= 1000
# Out:
# ['4.50 GHz' '4.60 GHz' '4.40 GHz' '4.10 GHz' '4.00 GHz' '3.60 GHz'
#  '3.80 GHz' '3.70 GHz' '3.50 GHz' '3.90 GHz' '6.00 GHz' '5.60 GHz'
#  '5.20 GHz' '5.40 GHz' '5.30 GHz' '5.00 GHz' '5.50 GHz' '5.80 GHz'
#  '4.90 GHz' '5.10 GHz' '4.80 GHz' '4.70 GHz' '4.20 GHz' nan '4.30 GHz'
#  '3.40 GHz' '2.90 GHz' '3.20 GHz' '3.00 GHz' '3.30 GHz' '2.80 GHz'
#  '2.70 GHz' '3.10 GHz' '2.20 GHz' '2.60 GHz' '3.73 GHz' '3.33 GHz'
#  '2.93 GHz' '3.46 GHz' '3.86 GHz' '3.07 GHz' '3.06 GHz']
# ['3.70 GHz' '3.50 GHz' '3.30 GHz' '3.00 GHz' '3.80 GHz' '3.10 GHz'
#  '3.40 GHz' '3.60 GHz' '3.20 GHz' nan '1.80 GHz' '1.00 GHz' '1.70 GHz'
#  '1.90 GHz' '1.10 GHz' '2.50 GHz' '1.30 GHz' '2.40 GHz' '1.40 GHz'
#  '2.70 GHz' '1.20 GHz' '2.10 GHz' '2.30 GHz' '1.60 GHz' '1.50 GHz'
#  '2.60 GHz' '2.80 GHz' '3.90 GHz' '2.20 GHz' '2.90 GHz' '2.00 GHz'
#  '4.10 GHz' '4.00 GHz' '4.20 GHz' '900 MHz' '800 MHz' '3.33 GHz'
#  '3.46 GHz' '1.73 GHz' '1.86 GHz' '2.93 GHz' '3.06 GHz' '2.53 GHz'
#  '2.13 GHz' '2.66 GHz' '2.83 GHz' '2.33 GHz' '2.26 GHz' '3.16 GHz']

# %%
for i in range(df.shape[0]):
    if "L2" in df.iloc[i, 7]:
        df.loc[i, "Cache"] = 1
    elif "L3" in df.iloc[i, 7]:
        df.loc[i, "Cache"] = 2
    elif "Intel® Smart Cache" in df.iloc[i, 7]:
        df.loc[i, "Cache"] = 3
    else:
        df.loc[i, "Cache"] = 0
        
df["Cache"] = pd.to_numeric(df["Cache"])

print(df["Cache"].unique())
# Out:
# [3 2 0 1]

# %%
df.drop("Bus", axis=1, inplace=True)

# %%
df["MaxTDP"] = pd.to_numeric(df["MaxTDP"].str.replace(" W", ""), errors='coerce')

# %%
df.drop("BornOnDate", axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595 entries, 0 to 594
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Model          595 non-null    object
#  1   Price          595 non-null    float64
#  2   Lithography    436 non-null    float64
#  3   CoreCount      595 non-null    float64
#  4   ThreadCount    567 non-null    float64
#  5   ClockSpeedMax  511 non-null    float64
#  6   ClockSpeed     431 non-null    float64
#  7   Cache          595 non-null    int64
#  8   MaxTDP         420 non-null    float64
#  9   Desktop        595 non-null    bool
#  10  Embedded       595 non-null    bool
#  11  Mobile         595 non-null    bool
# dtypes: bool(3), float64(7), int64(1), object(1)
# memory usage: 43.7+ KB

# %%
df.describe()
# Out:
#              Price  Lithography   CoreCount  ThreadCount  ClockSpeedMax  \
# count   595.000000   436.000000  595.000000   567.000000     511.000000
# mean    342.857983    19.518349    6.509244    10.744268       4.231800
# std     207.161215    10.328273    4.606521     6.836805       0.664087
# min      97.000000    10.000000    2.000000     4.000000       2.200000
# 25%     213.000000    14.000000    4.000000     4.000000       3.700000
# 50%     309.000000    14.000000    4.000000     8.000000       4.400000
# 75%     415.500000    22.000000    8.000000    16.000000       4.700000
# max    1979.000000    45.000000   24.000000    36.000000       6.000000
#
#        ClockSpeed       Cache      MaxTDP
# count  431.000000  595.000000  420.000000
# mean     2.706450    2.756303   59.402381
# std      0.729379    0.760630   37.939076
# min      0.800000    0.000000    4.500000
# 25%      2.300000    3.000000   35.000000
# 50%      2.800000    3.000000   54.000000
# 75%      3.300000    3.000000   77.000000
# max      4.200000    3.000000  165.000000

# %%
df.drop("MaxTDP", axis=1, inplace=True)

imputations = df.columns[df.isnull().any()]

for i in imputations:
    df[i].fillna(df[i].median(), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595 entries, 0 to 594
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Model          595 non-null    object
#  1   Price          595 non-null    float64
#  2   Lithography    595 non-null    float64
#  3   CoreCount      595 non-null    float64
#  4   ThreadCount    595 non-null    float64
#  5   ClockSpeedMax  595 non-null    float64
#  6   ClockSpeed     595 non-null    float64
#  7   Cache          595 non-null    int64
#  8   Desktop        595 non-null    bool
#  9   Embedded       595 non-null    bool
#  10  Mobile         595 non-null    bool
# dtypes: bool(3), float64(6), int64(1), object(1)
# memory usage: 39.1+ KB

# %%
df.to_csv("Intel_CPUs_cleaned.csv", index=False)
